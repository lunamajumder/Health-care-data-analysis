# %% [markdown]
# <a href="https://colab.research.google.com/github/lunamajumder/Health-care-data-analysis/blob/main/Health_care_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Default title text

# Import pandas
import pandas as pd

# Load the CSV file from Google Drive
df = pd.read_csv('/content/drive/MyDrive/total.csv')

# %%
# @title Unplanned Readmission in different Measure

df.groupby('Measure').size().sort_values(ascending=True).plot(kind='barh', color='skyblue')

# Clean up plot appearance
plt.gca().spines[['top', 'right']].set_visible(False)
plt.title('Unplanned Readmissions by Measure')
plt.xlabel('Number of Readmissions')
plt.ylabel('Measure')
plt.tight_layout()
plt.show()

# %%
# @title Readmission to Same Hospital or not

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Readmission_to_Same_Hospital_or_not').size().plot(kind='barh')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Readmission to Same Hospital or not')
# Out:
# Text(0.5, 1.0, 'Readmission to Same Hospital or not')

# %%
# @title Pneumonia patients had the longest average length of stay during the initial admission.

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['Measure'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Admission.LOS', y='Measure', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
plt.title('Pneumonia patients had the longest average length of stay during the initial admission.')
# Out:
# <ipython-input-13-9e3256e7c66c>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='Admission.LOS', y='Measure', inner='stick', palette='Dark2')
# Text(0.5, 1.0, 'Pneumonia patients had the longest average length of stay during the initial admission.')

# %%
# @title Among unplanned readmissions, Stroke patients had the longest average length of stay, followed by those with COPD, Heart Failure, and Pneumonia.
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['Measure'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Readmission.LOS', y='Measure', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
plt.title('Among unplanned readmissions, Stroke patients had the longest average length of stay, followed by those with COPD, Heart Failure, and Pneumonia.')
# Out:
# <ipython-input-14-d2740c422bf2>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='Readmission.LOS', y='Measure', inner='stick', palette='Dark2')
# Text(0.5, 1.0, 'Among unplanned readmissions, Stroke patients had the longest average length of stay, followed by those with COPD, Heart Failure, and Pneumonia.')

# %%
# @title A strong correlation was observed between the length of stay during the initial admission and that of the unplanned readmission.

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Admission.LOS', y='Readmission.LOS', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('A strong correlation was observed between the length of stay during the initial admission and that of the unplanned readmission.')
# Out:
# Text(0.5, 1.0, 'A strong correlation was observed between the length of stay during the initial admission and that of the unplanned readmission.')
